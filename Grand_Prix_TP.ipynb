# %% [markdown]
# # Exercice 5 : Grand prix de Mexico – F1
#
# Le grand prix de Mexico a livré un beau spectacle dimanche 30 octobre 2022 et a vu Max Verstappen s’imposer et ainsi, battre un nouveau record historique. L’occasion de s’intéresser d’un peu plus près à la Formule 1, discipline reine des sports mécaniques.
#
# ## Question 1 : Classe « F1 »
#
# Créer une classe `F1` qui comporte :
#
# - **Attributs** :
#   - `moteur` : représente la puissance théorique du moteur (par exemple, "500cv").
#   - `temperature_pneumatique` : température initiale des pneus fixée à 110°.
#   - `vitesse` : vitesse en km/h de la F1, fixée à 200 km/h.
#   - `temperature_moteur` : calculée selon la formule :
#   - (température pneumatique x 0.09 ) x ( vitesse x 0.11 ).
#   - `position` : indique la position du pilote sur le circuit (place, rang).
#
# - **Méthodes** :
#   - `moteur_is_dead()`: retourne un booléen pour indiquer une panne moteur ou non (si la température moteur > 360°).
#   - `accélérer(n)`: permet à la F1 d’accélérer de `n` km/h et augmente la vitesse.
#   - `DRS()`: permet de gagner 15% de vitesse supplémentaire sur la méthode `accélérer` appelée dans cette méthode.
#   - `dépassement()`: permet à un pilote de dépasser un autre pilote (gagner ou perdre des places). Gestion des exceptions pour empêcher de dépasser un pilote qui est derrière.
#   - Redéfinition de `__str__()`: affiche les informations de la F1.
#
# ---
#
# ## Question 2 : Les écuries et les pilotes (Héritage)
#
# En F1, il existe plusieurs écuries : **RedBull Racing**, **Mercedes**, et **Ferrari**.
#
# ### RedBull
# - Possède un nouvel aileron avant :
#   - Lorsqu’ils dépassent une Mercedes, leur température pneumatique diminue de 8% tandis qu’elle augmente de 12% chez Mercedes.
#   - Pour Ferrari, ce rapport est de 8% et 14%, respectivement.
#
# ### Mercedes
# - Grâce à leurs ingénieurs d’expérience :
#   - Lorsqu’ils dépassent une autre écurie, ils diminuent la température de leurs pneumatiques de 11%.
#
# ### Ferrari
# - En cas de dépassement subi :
#   - Perturbations aérodynamiques qui réduisent aléatoirement la vitesse de la voiture entre 5 et 12 km/h.
#
# ---
#
# ## Question 3 : C’est l’heure de la course !
#
# ### Instructions :
# 1. **Définir les positions** des écuries selon votre choix (1, 2, 3).
# 2. **Effectuer des dépassements** sur le circuit de Mexico, en poussant les F1 des 3 écuries au maximum de leurs capacités.
# 3. **Simuler une panne moteur** pour l’une des F1 (`moteur_is_dead`).
#
# ### Contraintes :
# - Utiliser au maximum les notions vues en cours : constructeurs, héritage, setters, gestion des exceptions, etc.
# - Livrer un fichier `circuit.py` contenant les classes ainsi qu’un exécutable à la fin du fichier.
#
# ---
#
# ### Livrable attendu :
# Un fichier unique nommé `circuit.py` (sans import externe). Respecter les bonnes pratiques.
# La course dure 1h30 : **MONTER LE VOLUME ET RENDEZ VOUS AU PREMIER VIRAGE !**

# %%
import random

class F1:
    def __init__(self, moteur: int, position: int, ecurie: str):
        self.__moteur = moteur
        self.__position = position
        self.__vitesse = 200
        self.__temperature_pneumatiques = 110
        self.__temperature_moteur = (self.__temperature_pneumatiques * 0.09) * (self.__vitesse * 0.11)
        self.__ecurie = ecurie

    def moteur_is_dead(self) -> bool:
        if self.__temperature_moteur > 360:
            return True
        return False

    def accelerer(self, km: int) -> None:
        self.__vitesse += km
        self.__temperature_moteur = (self.__temperature_pneumatiques * 0.09) * (self.__vitesse * 0.11)

    def DRS(self) -> None:
        self.accelerer(int(self.__vitesse * 0.15))

    def depassement(self, voiture: 'F1') -> None:
        if self.__position <= voiture.position:
            if voiture.position < 3:  # Limiter la position à un maximum de 3
                voiture.position += 1
            if self.__position > 1:  # Limiter la position à un minimum de 1
                self.__position -= 1
        else:
            print(f"{self.ecurie} ne peut pas dépasser {voiture.ecurie} car elle est déjà derrière.")

    @property
    def moteur(self):
        return self.__moteur

    @property
    def position(self):
        return self.__position

    @position.setter
    def position(self, value):
        self.__position = value

    @property
    def vitesse(self):
        return self.__vitesse

    @property
    def temperature_pneumatiques(self):
        return self.__temperature_pneumatiques

    @property
    def temperature_moteur(self):
        return self.__temperature_moteur
    
    @temperature_moteur.setter
    def temperature_moteur(self, value):
        self.__temperature_moteur = value

    @property
    def ecurie(self):
        return self.__ecurie

    def __str__(self):
        return (f"{self.__ecurie}: {self.__moteur}cv, Vitesse: {self.__vitesse} km/h, "
                f"Température Pneumatiques: {self.__temperature_pneumatiques}°, "
                f"Température Moteur: {self.__temperature_moteur}°, Position: {self.__position}")

# %%
class RedBull(F1):
    def __init__(self, moteur: int, position: int):
        super().__init__(moteur, position, "RedBull")

    def depassement(self, voiture: 'F1') -> None:
        super().depassement(voiture)
        if isinstance(voiture, Mercedes):
            self._F1__temperature_pneumatiques *= 0.92
            voiture._F1__temperature_pneumatiques *= 1.12
        elif isinstance(voiture, Ferrari):
            self._F1__temperature_pneumatiques *= 0.92
            voiture._F1__temperature_pneumatiques *= 1.14

# %%
class Mercedes(F1):
    def __init__(self, moteur: int, position: int):
        super().__init__(moteur, position, "Mercedes")

    def depassement(self, voiture: 'F1') -> None:
        super().depassement(voiture)
        self._F1__temperature_pneumatiques *= 0.89

# %%
class Ferrari(F1):
    def __init__(self, moteur: int, position: int):
        super().__init__(moteur, position, "Ferrari")

    def depassement(self, voiture: 'F1') -> None:
        super().depassement(voiture)

    def subit_depassement(self) -> None:
        reduction = random.randint(5, 12)
        self._F1__vitesse -= reduction
        self._F1__temperature_moteur = (self._F1__temperature_pneumatiques * 0.09) * (self._F1__vitesse * 0.11)

# %%
# Simulation de la course
def simulation_course():
    # Initialisation des voitures
    redbull = RedBull(moteur=500, position=1)
    mercedes = Mercedes(moteur=550, position=2)
    ferrari = Ferrari(moteur=600, position=3)
    
    for tour in range(1, 12):
        print(f"\n--- Tour {tour} ---")

        # Affichage initial
        print("--- Début du tour ---")
        print(redbull)
        print(mercedes)
        print(ferrari)

        # RedBull dépasse Mercedes
        print("\nRedBull dépasse Mercedes !")
        dépassement1 = random.choice([mercedes, ferrari])
        redbull.depassement(dépassement1)
        print(redbull)
        print(dépassement1)

        # Mercedes dépasse Ferrari
        print("\nMercedes dépasse Ferrari !")
        dépassement2 = random.choice([redbull, ferrari])
        mercedes.depassement(dépassement2)
        print(mercedes)
        print(dépassement2)

        # Ferrari subit un dépassement
        print("\nFerrari subit un dépassement !")
        ferrari.subit_depassement()
        print(ferrari)

        # Accélération et DRS
        print("\nRedBull utilise DRS !")
        redbull.DRS()
        print(redbull)

        # Simulation de moteur cassé
        print("\nSimulation d'une panne moteur pour RedBull")
        if redbull.moteur_is_dead():
            print("Le moteur de la RedBull est cassé et la voiture est immobilisée !")
        else:
            print("Le moteur de la RedBull fonctionne encore normalement.")
        
        print(redbull.temperature_moteur)

        print("\n--- Fin du tour ---")

# %%
simulation_course()
# Out:
# --- Tour 1 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 200 km/h, Température Pneumatiques: 110°, Température Moteur: 217.8°, Position: 1
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 110°, Température Moteur: 217.8°, Position: 2
# Ferrari: 600cv, Vitesse: 200 km/h, Température Pneumatiques: 110°, Température Moteur: 217.8°, Position: 3
#
# RedBull dépasse Mercedes !
# RedBull: 500cv, Vitesse: 200 km/h, Température Pneumatiques: 101.2°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 200 km/h, Température Pneumatiques: 125.39999999999999°, Température Moteur: 217.8°, Position: 3
#
# Mercedes dépasse Ferrari !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 97.9°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 200 km/h, Température Pneumatiques: 125.39999999999999°, Température Moteur: 217.8°, Position: 3
#
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 188 km/h, Température Pneumatiques: 125.39999999999999°, Température Moteur: 233.39448°, Position: 3
#
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 230 km/h, Température Pneumatiques: 101.2°, Température Moteur: 230.43240000000003°, Position: 1
#
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# 230.43240000000003
#
# --- Fin du tour ---
#
# --- Tour 2 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 230 km/h, Température Pneumatiques: 101.2°, Température Moteur: 230.43240000000003°, Position: 1
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 97.9°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 188 km/h, Température Pneumatiques: 125.39999999999999°, Température Moteur: 233.39448°, Position: 3
#
# RedBull dépasse Mercedes !
# RedBull: 500cv, Vitesse: 230 km/h, Température Pneumatiques: 93.10400000000001°, Température Moteur: 230.43240000000003°, Position: 1
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 109.64800000000001°, Température Moteur: 217.8°, Position: 2
#
# Mercedes dépasse Ferrari !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 97.58672000000001°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 188 km/h, Température Pneumatiques: 125.39999999999999°, Température Moteur: 233.39448°, Position: 3
#
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 180 km/h, Température Pneumatiques: 125.39999999999999°, Température Moteur: 223.4628°, Position: 3
#
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 264 km/h, Température Pneumatiques: 93.10400000000001°, Température Moteur: 243.3366144°, Position: 1
#
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# 243.3366144
#
# --- Fin du tour ---
#
# --- Tour 3 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 264 km/h, Température Pneumatiques: 93.10400000000001°, Température Moteur: 243.3366144°, Position: 1
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 97.58672000000001°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 180 km/h, Température Pneumatiques: 125.39999999999999°, Température Moteur: 223.4628°, Position: 3
#
# RedBull dépasse Mercedes !
# RedBull: 500cv, Vitesse: 264 km/h, Température Pneumatiques: 85.65568000000002°, Température Moteur: 243.3366144°, Position: 1
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 109.29712640000002°, Température Moteur: 217.8°, Position: 2
#
# Mercedes dépasse Ferrari !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 97.27444249600002°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 180 km/h, Température Pneumatiques: 125.39999999999999°, Température Moteur: 223.4628°, Position: 3
#
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 170 km/h, Température Pneumatiques: 125.39999999999999°, Température Moteur: 211.04819999999998°, Position: 3
#
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 303 km/h, Température Pneumatiques: 85.65568000000002°, Température Moteur: 256.94134329600007°, Position: 1
#
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# 256.94134329600007
#
# --- Fin du tour ---
#
# --- Tour 4 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 303 km/h, Température Pneumatiques: 85.65568000000002°, Température Moteur: 256.94134329600007°, Position: 1
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 97.27444249600002°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 170 km/h, Température Pneumatiques: 125.39999999999999°, Température Moteur: 211.04819999999998°, Position: 3
#
# RedBull dépasse Mercedes !
# RedBull: 500cv, Vitesse: 303 km/h, Température Pneumatiques: 78.80322560000002°, Température Moteur: 256.94134329600007°, Position: 1
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 108.94737559552003°, Température Moteur: 217.8°, Position: 2
#
# Mercedes dépasse Ferrari !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 96.96316428001283°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 170 km/h, Température Pneumatiques: 125.39999999999999°, Température Moteur: 211.04819999999998°, Position: 3
#
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 163 km/h, Température Pneumatiques: 125.39999999999999°, Température Moteur: 202.35798°, Position: 3
#
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 348 km/h, Température Pneumatiques: 78.80322560000002°, Température Moteur: 271.49287283712005°, Position: 1
#
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# 271.49287283712005
#
# --- Fin du tour ---
#
# --- Tour 5 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 348 km/h, Température Pneumatiques: 78.80322560000002°, Température Moteur: 271.49287283712005°, Position: 1
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 96.96316428001283°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 163 km/h, Température Pneumatiques: 125.39999999999999°, Température Moteur: 202.35798°, Position: 3
#
# RedBull dépasse Mercedes !
# RedBull: 500cv, Vitesse: 348 km/h, Température Pneumatiques: 72.49896755200002°, Température Moteur: 271.49287283712005°, Position: 1
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 108.59874399361438°, Température Moteur: 217.8°, Position: 2
#
# Mercedes dépasse Ferrari !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 96.6528821543168°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 163 km/h, Température Pneumatiques: 125.39999999999999°, Température Moteur: 202.35798°, Position: 3
#
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 151 km/h, Température Pneumatiques: 125.39999999999999°, Température Moteur: 187.46045999999998°, Position: 3
#
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 400 km/h, Température Pneumatiques: 72.49896755200002°, Température Moteur: 287.09591150592007°, Position: 1
#
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# 287.09591150592007
#
# --- Fin du tour ---
#
# --- Tour 6 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 400 km/h, Température Pneumatiques: 72.49896755200002°, Température Moteur: 287.09591150592007°, Position: 1
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 96.6528821543168°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 151 km/h, Température Pneumatiques: 125.39999999999999°, Température Moteur: 187.46045999999998°, Position: 3
#
# RedBull dépasse Mercedes !
# RedBull: 500cv, Vitesse: 400 km/h, Température Pneumatiques: 66.69905014784003°, Température Moteur: 287.09591150592007°, Position: 1
# Ferrari: 600cv, Vitesse: 151 km/h, Température Pneumatiques: 142.956°, Température Moteur: 187.46045999999998°, Position: 3
#
# Mercedes dépasse Ferrari !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 86.02106511734195°, Température Moteur: 217.8°, Position: 1
# RedBull: 500cv, Vitesse: 400 km/h, Température Pneumatiques: 66.69905014784003°, Température Moteur: 287.09591150592007°, Position: 2
#
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 143 km/h, Température Pneumatiques: 142.956°, Température Moteur: 202.38280919999997°, Position: 3
#
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 460 km/h, Température Pneumatiques: 66.69905014784003°, Température Moteur: 303.74747437326346°, Position: 2
#
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# 303.74747437326346
#
# --- Fin du tour ---
#
# --- Tour 7 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 460 km/h, Température Pneumatiques: 66.69905014784003°, Température Moteur: 303.74747437326346°, Position: 2
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 86.02106511734195°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 143 km/h, Température Pneumatiques: 142.956°, Température Moteur: 202.38280919999997°, Position: 3
#
# RedBull dépasse Mercedes !
# RedBull ne peut pas dépasser Mercedes car elle est déjà derrière.
# RedBull: 500cv, Vitesse: 460 km/h, Température Pneumatiques: 61.36312613601282°, Température Moteur: 303.74747437326346°, Position: 2
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 96.34359293142299°, Température Moteur: 217.8°, Position: 1
#
# Mercedes dépasse Ferrari !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 85.74579770896646°, Température Moteur: 217.8°, Position: 1
# RedBull: 500cv, Vitesse: 460 km/h, Température Pneumatiques: 61.36312613601282°, Température Moteur: 303.74747437326346°, Position: 3
#
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 136 km/h, Température Pneumatiques: 142.956°, Température Moteur: 192.4759584°, Position: 3
#
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 529 km/h, Température Pneumatiques: 61.36312613601282°, Température Moteur: 321.36482788691274°, Position: 3
#
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# 321.36482788691274
#
# --- Fin du tour ---
#
# --- Tour 8 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 529 km/h, Température Pneumatiques: 61.36312613601282°, Température Moteur: 321.36482788691274°, Position: 3
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 85.74579770896646°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 136 km/h, Température Pneumatiques: 142.956°, Température Moteur: 192.4759584°, Position: 3
#
# RedBull dépasse Mercedes !
# RedBull: 500cv, Vitesse: 529 km/h, Température Pneumatiques: 56.4540760451318°, Température Moteur: 321.36482788691274°, Position: 2
# Ferrari: 600cv, Vitesse: 136 km/h, Température Pneumatiques: 162.96983999999998°, Température Moteur: 192.4759584°, Position: 3
#
# Mercedes dépasse Ferrari !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 76.31375996098015°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 136 km/h, Température Pneumatiques: 162.96983999999998°, Température Moteur: 192.4759584°, Position: 3
#
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 128 km/h, Température Pneumatiques: 162.96983999999998°, Température Moteur: 206.51538124799998°, Position: 3
#
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 608 km/h, Température Pneumatiques: 56.4540760451318°, Température Moteur: 339.8083745308573°, Position: 2
#
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# 339.8083745308573
#
# --- Fin du tour ---
#
# --- Tour 9 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 608 km/h, Température Pneumatiques: 56.4540760451318°, Température Moteur: 339.8083745308573°, Position: 2
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 76.31375996098015°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 128 km/h, Température Pneumatiques: 162.96983999999998°, Température Moteur: 206.51538124799998°, Position: 3
#
# RedBull dépasse Mercedes !
# RedBull ne peut pas dépasser Mercedes car elle est déjà derrière.
# RedBull: 500cv, Vitesse: 608 km/h, Température Pneumatiques: 51.937749961521256°, Température Moteur: 339.8083745308573°, Position: 2
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 85.47141115629778°, Température Moteur: 217.8°, Position: 1
#
# Mercedes dépasse Ferrari !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 76.06955592910502°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 128 km/h, Température Pneumatiques: 162.96983999999998°, Température Moteur: 206.51538124799998°, Position: 3
#
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 120 km/h, Température Pneumatiques: 162.96983999999998°, Température Moteur: 193.60816991999997°, Position: 3
#
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 699 km/h, Température Pneumatiques: 51.937749961521256°, Température Moteur: 359.41442350872325°, Position: 2
#
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# 359.41442350872325
#
# --- Fin du tour ---
#
# --- Tour 10 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 699 km/h, Température Pneumatiques: 51.937749961521256°, Température Moteur: 359.41442350872325°, Position: 2
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 76.06955592910502°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 120 km/h, Température Pneumatiques: 162.96983999999998°, Température Moteur: 193.60816991999997°, Position: 3
#
# RedBull dépasse Mercedes !
# RedBull ne peut pas dépasser Mercedes car elle est déjà derrière.
# RedBull: 500cv, Vitesse: 699 km/h, Température Pneumatiques: 47.782729964599554°, Température Moteur: 359.41442350872325°, Position: 2
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 85.19790264059763°, Température Moteur: 217.8°, Position: 1
#
# Mercedes dépasse Ferrari !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 75.8261333501319°, Température Moteur: 217.8°, Position: 1
# RedBull: 500cv, Vitesse: 699 km/h, Température Pneumatiques: 47.782729964599554°, Température Moteur: 359.41442350872325°, Position: 3
#
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 114 km/h, Température Pneumatiques: 162.96983999999998°, Température Moteur: 183.92776142399998°, Position: 3
#
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 803 km/h, Température Pneumatiques: 47.782729964599554°, Température Moteur: 379.858368399577°, Position: 3
#
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull est cassé et la voiture est immobilisée !
# 379.858368399577
#
# --- Fin du tour ---
#
# --- Tour 11 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 803 km/h, Température Pneumatiques: 47.782729964599554°, Température Moteur: 379.858368399577°, Position: 3
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 75.8261333501319°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 114 km/h, Température Pneumatiques: 162.96983999999998°, Température Moteur: 183.92776142399998°, Position: 3
#
# RedBull dépasse Mercedes !
# RedBull: 500cv, Vitesse: 803 km/h, Température Pneumatiques: 43.96011156743159°, Température Moteur: 379.858368399577°, Position: 2
# Ferrari: 600cv, Vitesse: 114 km/h, Température Pneumatiques: 185.78561759999997°, Température Moteur: 183.92776142399998°, Position: 3
#
# Mercedes dépasse Ferrari !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 67.4852586816174°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 114 km/h, Température Pneumatiques: 185.78561759999997°, Température Moteur: 183.92776142399998°, Position: 3
#
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 102 km/h, Température Pneumatiques: 185.78561759999997°, Température Moteur: 187.60631665248°, Position: 3
#
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 923 km/h, Température Pneumatiques: 43.96011156743159°, Température Moteur: 401.69431146971965°, Position: 2
#
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull est cassé et la voiture est immobilisée !
# 401.69431146971965
#
# --- Fin du tour ---
