# %% [markdown]
# # Exercice 5 : Grand prix de Mexico – F1
#
# Le grand prix de Mexico a livré un beau spectacle dimanche 30 octobre 2022 et a vu Max Verstappen s’imposer et ainsi, battre un nouveau record historique. L’occasion de s’intéresser d’un peu plus près à la Formule 1, discipline reine des sports mécaniques.
#
# ## Question 1 : Classe « F1 »
#
# Créer une classe `F1` qui comporte :
#
# - **Attributs** :
#   - `moteur` : représente la puissance théorique du moteur (par exemple, "500cv").
#   - `temperature_pneumatique` : température initiale des pneus fixée à 110°.
#   - `vitesse` : vitesse en km/h de la F1, fixée à 200 km/h.
#   - `temperature_moteur` : calculée selon la formule :
#   - (température pneumatique x 0.09 ) x ( vitesse x 0.11 ).
#   - `position` : indique la position du pilote sur le circuit (place, rang).
#
# - **Méthodes** :
#   - `moteur_is_dead()`: retourne un booléen pour indiquer une panne moteur ou non (si la température moteur > 360°).
#   - `accélérer(n)`: permet à la F1 d’accélérer de `n` km/h et augmente la vitesse.
#   - `DRS()`: permet de gagner 15% de vitesse supplémentaire sur la méthode `accélérer` appelée dans cette méthode.
#   - `dépassement()`: permet à un pilote de dépasser un autre pilote (gagner ou perdre des places). Gestion des exceptions pour empêcher de dépasser un pilote qui est derrière.
#   - Redéfinition de `__str__()`: affiche les informations de la F1.
#
# ---
#
# ## Question 2 : Les écuries et les pilotes (Héritage)
#
# En F1, il existe plusieurs écuries : **RedBull Racing**, **Mercedes**, et **Ferrari**.
#
# ### RedBull
# - Possède un nouvel aileron avant :
#   - Lorsqu’ils dépassent une Mercedes, leur température pneumatique diminue de 8% tandis qu’elle augmente de 12% chez Mercedes.
#   - Pour Ferrari, ce rapport est de 8% et 14%, respectivement.
#
# ### Mercedes
# - Grâce à leurs ingénieurs d’expérience :
#   - Lorsqu’ils dépassent une autre écurie, ils diminuent la température de leurs pneumatiques de 11%.
#
# ### Ferrari
# - En cas de dépassement subi :
#   - Perturbations aérodynamiques qui réduisent aléatoirement la vitesse de la voiture entre 5 et 12 km/h.
#
# ---
#
# ## Question 3 : C’est l’heure de la course !
#
# ### Instructions :
# 1. **Définir les positions** des écuries selon votre choix (1, 2, 3).
# 2. **Effectuer des dépassements** sur le circuit de Mexico, en poussant les F1 des 3 écuries au maximum de leurs capacités.
# 3. **Simuler une panne moteur** pour l’une des F1 (`moteur_is_dead`).
#
# ### Contraintes :
# - Utiliser au maximum les notions vues en cours : constructeurs, héritage, setters, gestion des exceptions, etc.
# - Livrer un fichier `circuit.py` contenant les classes ainsi qu’un exécutable à la fin du fichier.
#
# ---
#
# ### Livrable attendu :
# Un fichier unique nommé `circuit.py` (sans import externe). Respecter les bonnes pratiques.
# La course dure 1h30 : **MONTER LE VOLUME ET RENDEZ VOUS AU PREMIER VIRAGE !**

# %%
import random

class F1:
    def __init__(self, moteur: int, position: int, ecurie: str):
        self.__moteur = moteur
        self.__position = position
        self.__vitesse = 200
        self.__temperature_pneumatiques = 110
        self.__temperature_moteur = (self.__temperature_pneumatiques * 0.09) * (self.__vitesse * 0.11)
        self.__ecurie = ecurie

    def moteur_is_dead(self) -> bool:
        if self.__temperature_moteur > 360:
            return True
        return False

    def accelerer(self, km: int) -> None:
        self.__vitesse += km
        self.__temperature_moteur = (self.__temperature_pneumatiques * 0.09) * (self.__vitesse * 0.11)

    def DRS(self) -> None:
        self.accelerer(int(self.__vitesse * 0.15))

    def depassement(self, voiture: 'F1', toutes_voitures: list) -> None:
        if self.__position < voiture.position:
            print(f"{self.__ecurie} ne peut pas dépasser {voiture.ecurie} car elle est déjà derrière.")
        elif self.__position == voiture.position +1:
            # Effectuer le dépassement
            self.__position, voiture.position = voiture.position, self.__position
            print(f"{self.__ecurie} dépasse {voiture.ecurie} !")
        else:
            print(f"{self.__ecurie} ne peut pas dépasser {voiture.ecurie} directement.")
            return
        
        # Réorganiser les positions pour garantir un ordre unique (1, 2, 3)
        toutes_voitures.sort(key=lambda v: v.position)
        for i, voiture in enumerate(toutes_voitures, start=1):
            voiture.position = i

    @property
    def moteur(self):
        return self.__moteur

    @property
    def position(self):
        return self.__position

    @position.setter
    def position(self, value):
        self.__position = value

    @property
    def vitesse(self):
        return self.__vitesse

    @property
    def temperature_pneumatiques(self):
        return self.__temperature_pneumatiques

    @property
    def temperature_moteur(self):
        return self.__temperature_moteur
    
    @temperature_moteur.setter
    def temperature_moteur(self, value):
        self.__temperature_moteur = value

    @property
    def ecurie(self):
        return self.__ecurie

    def __str__(self):
        return (f"{self.__ecurie}: {self.__moteur}cv, Vitesse: {self.__vitesse} km/h, "
                f"Température Pneumatiques: {round(self.__temperature_pneumatiques, 2)}°, "
                f"Température Moteur: {round(self.__temperature_moteur, 2)}°, Position: {self.__position}")

# %%
class RedBull(F1):
    def __init__(self, moteur: int, position: int):
        super().__init__(moteur, position, "RedBull")

    def depassement(self, voiture: 'F1', toutes_voitures: list) -> None:
        super().depassement(voiture, toutes_voitures)
        if isinstance(voiture, Mercedes):
            self._F1__temperature_pneumatiques *= 0.92
            voiture._F1__temperature_pneumatiques *= 1.12
        elif isinstance(voiture, Ferrari):
            self._F1__temperature_pneumatiques *= 0.92
            voiture._F1__temperature_pneumatiques *= 1.14

# %%
class Mercedes(F1):
    def __init__(self, moteur: int, position: int):
        super().__init__(moteur, position, "Mercedes")

    def depassement(self, voiture: 'F1', toutes_voitures: list) -> None:
        super().depassement(voiture, toutes_voitures)
        self._F1__temperature_pneumatiques *= 0.89

# %%
class Ferrari(F1):
    def __init__(self, moteur: int, position: int):
        super().__init__(moteur, position, "Ferrari")

    def depassement(self, voiture: 'F1', toutes_voitures: list) -> None:
        super().depassement(voiture, toutes_voitures)

    def subit_depassement(self) -> None:
        reduction = random.randint(5, 12)
        self._F1__vitesse -= reduction
        self._F1__temperature_moteur = (self._F1__temperature_pneumatiques * 0.09) * (self._F1__vitesse * 0.11)

# %%
def simulation_course():
    # Initialisation des voitures
    redbull = RedBull(moteur=500, position=1)
    mercedes = Mercedes(moteur=550, position=2)
    ferrari = Ferrari(moteur=600, position=3)
    toutes_voitures = [redbull, mercedes, ferrari]
    
    for tour in range(1, 11):
        print(f"\n--- Tour {tour} ---")

        # Affichage initial
        print("--- Début du tour ---")
        print(redbull)
        print(mercedes)
        print(ferrari)

        # RedBull dépasse une voiture
        print("RedBull tente un dépassement !")
        cible1 = random.choice([mercedes, ferrari])
        redbull.depassement(cible1, toutes_voitures)
        print(redbull)
        print(cible1)

        # Mercedes dépasse une voiture
        print("Mercedes tente un dépassement !")
        cible2 = random.choice([redbull, ferrari])
        mercedes.depassement(cible2, toutes_voitures)
        print(mercedes)
        print(cible2)
        
        # Ferrari dépasse une voiture
        print("Ferrari tente un dépassement !")
        cible3 = random.choice([redbull, mercedes])
        ferrari.depassement(cible3, toutes_voitures)
        print(mercedes)
        print(cible3)

        # Ferrari subit un dépassement (température et vitesse réduites)
        print("Ferrari subit un dépassement !")
        ferrari.subit_depassement()
        print(ferrari)

        # RedBull utilise DRS pour accélérer
        print("RedBull utilise DRS !")
        redbull.DRS()
        print(redbull)

        # Vérification des pannes moteur
        print("Simulation d'une panne moteur pour RedBull")
        if redbull.moteur_is_dead():
            print("Le moteur de la RedBull est cassé et la voiture est immobilisée !")
        else:
            print("Le moteur de la RedBull fonctionne encore normalement.")
        
        # Affichage de la température moteur
        print(f"Température moteur RedBull : {round(redbull.temperature_moteur, 2)}")

        print("\n--- Fin du tour ---")

# %%
simulation_course()
# Out:
# --- Tour 1 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 200 km/h, Température Pneumatiques: 110°, Température Moteur: 217.8°, Position: 1
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 110°, Température Moteur: 217.8°, Position: 2
# Ferrari: 600cv, Vitesse: 200 km/h, Température Pneumatiques: 110°, Température Moteur: 217.8°, Position: 3
# RedBull tente un dépassement !
# RedBull ne peut pas dépasser Ferrari car elle est déjà derrière.
# RedBull: 500cv, Vitesse: 200 km/h, Température Pneumatiques: 101.2°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 200 km/h, Température Pneumatiques: 125.4°, Température Moteur: 217.8°, Position: 3
# Mercedes tente un dépassement !
# Mercedes dépasse RedBull !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 97.9°, Température Moteur: 217.8°, Position: 1
# RedBull: 500cv, Vitesse: 200 km/h, Température Pneumatiques: 101.2°, Température Moteur: 217.8°, Position: 2
# Ferrari tente un dépassement !
# Ferrari dépasse RedBull !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 97.9°, Température Moteur: 217.8°, Position: 1
# RedBull: 500cv, Vitesse: 200 km/h, Température Pneumatiques: 101.2°, Température Moteur: 217.8°, Position: 3
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 189 km/h, Température Pneumatiques: 125.4°, Température Moteur: 234.64°, Position: 2
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 230 km/h, Température Pneumatiques: 101.2°, Température Moteur: 230.43°, Position: 3
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# Température moteur RedBull : 230.43
#
# --- Fin du tour ---
#
# --- Tour 2 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 230 km/h, Température Pneumatiques: 101.2°, Température Moteur: 230.43°, Position: 3
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 97.9°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 189 km/h, Température Pneumatiques: 125.4°, Température Moteur: 234.64°, Position: 2
# RedBull tente un dépassement !
# RedBull ne peut pas dépasser Mercedes directement.
# RedBull: 500cv, Vitesse: 230 km/h, Température Pneumatiques: 93.1°, Température Moteur: 230.43°, Position: 3
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 109.65°, Température Moteur: 217.8°, Position: 1
# Mercedes tente un dépassement !
# Mercedes ne peut pas dépasser RedBull car elle est déjà derrière.
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 97.59°, Température Moteur: 217.8°, Position: 1
# RedBull: 500cv, Vitesse: 230 km/h, Température Pneumatiques: 93.1°, Température Moteur: 230.43°, Position: 3
# Ferrari tente un dépassement !
# Ferrari ne peut pas dépasser RedBull car elle est déjà derrière.
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 97.59°, Température Moteur: 217.8°, Position: 1
# RedBull: 500cv, Vitesse: 230 km/h, Température Pneumatiques: 93.1°, Température Moteur: 230.43°, Position: 3
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 181 km/h, Température Pneumatiques: 125.4°, Température Moteur: 224.7°, Position: 2
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 264 km/h, Température Pneumatiques: 93.1°, Température Moteur: 243.34°, Position: 3
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# Température moteur RedBull : 243.34
#
# --- Fin du tour ---
#
# --- Tour 3 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 264 km/h, Température Pneumatiques: 93.1°, Température Moteur: 243.34°, Position: 3
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 97.59°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 181 km/h, Température Pneumatiques: 125.4°, Température Moteur: 224.7°, Position: 2
# RedBull tente un dépassement !
# RedBull dépasse Ferrari !
# RedBull: 500cv, Vitesse: 264 km/h, Température Pneumatiques: 85.66°, Température Moteur: 243.34°, Position: 2
# Ferrari: 600cv, Vitesse: 181 km/h, Température Pneumatiques: 142.96°, Température Moteur: 224.7°, Position: 3
# Mercedes tente un dépassement !
# Mercedes ne peut pas dépasser Ferrari car elle est déjà derrière.
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 86.85°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 181 km/h, Température Pneumatiques: 142.96°, Température Moteur: 224.7°, Position: 3
# Ferrari tente un dépassement !
# Ferrari ne peut pas dépasser Mercedes directement.
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 86.85°, Température Moteur: 217.8°, Position: 1
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 86.85°, Température Moteur: 217.8°, Position: 1
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 174 km/h, Température Pneumatiques: 142.96°, Température Moteur: 246.26°, Position: 3
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 303 km/h, Température Pneumatiques: 85.66°, Température Moteur: 256.94°, Position: 2
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# Température moteur RedBull : 256.94
#
# --- Fin du tour ---
#
# --- Tour 4 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 303 km/h, Température Pneumatiques: 85.66°, Température Moteur: 256.94°, Position: 2
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 86.85°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 174 km/h, Température Pneumatiques: 142.96°, Température Moteur: 246.26°, Position: 3
# RedBull tente un dépassement !
# RedBull dépasse Mercedes !
# RedBull: 500cv, Vitesse: 303 km/h, Température Pneumatiques: 78.8°, Température Moteur: 256.94°, Position: 1
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 97.27°, Température Moteur: 217.8°, Position: 2
# Mercedes tente un dépassement !
# Mercedes dépasse RedBull !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 86.57°, Température Moteur: 217.8°, Position: 1
# RedBull: 500cv, Vitesse: 303 km/h, Température Pneumatiques: 78.8°, Température Moteur: 256.94°, Position: 2
# Ferrari tente un dépassement !
# Ferrari dépasse RedBull !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 86.57°, Température Moteur: 217.8°, Position: 1
# RedBull: 500cv, Vitesse: 303 km/h, Température Pneumatiques: 78.8°, Température Moteur: 256.94°, Position: 3
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 163 km/h, Température Pneumatiques: 142.96°, Température Moteur: 230.69°, Position: 2
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 348 km/h, Température Pneumatiques: 78.8°, Température Moteur: 271.49°, Position: 3
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# Température moteur RedBull : 271.49
#
# --- Fin du tour ---
#
# --- Tour 5 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 348 km/h, Température Pneumatiques: 78.8°, Température Moteur: 271.49°, Position: 3
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 86.57°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 163 km/h, Température Pneumatiques: 142.96°, Température Moteur: 230.69°, Position: 2
# RedBull tente un dépassement !
# RedBull dépasse Ferrari !
# RedBull: 500cv, Vitesse: 348 km/h, Température Pneumatiques: 72.5°, Température Moteur: 271.49°, Position: 2
# Ferrari: 600cv, Vitesse: 163 km/h, Température Pneumatiques: 162.97°, Température Moteur: 230.69°, Position: 3
# Mercedes tente un dépassement !
# Mercedes ne peut pas dépasser Ferrari car elle est déjà derrière.
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 77.05°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 163 km/h, Température Pneumatiques: 162.97°, Température Moteur: 230.69°, Position: 3
# Ferrari tente un dépassement !
# Ferrari dépasse RedBull !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 77.05°, Température Moteur: 217.8°, Position: 1
# RedBull: 500cv, Vitesse: 348 km/h, Température Pneumatiques: 72.5°, Température Moteur: 271.49°, Position: 3
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 151 km/h, Température Pneumatiques: 162.97°, Température Moteur: 243.62°, Position: 2
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 400 km/h, Température Pneumatiques: 72.5°, Température Moteur: 287.1°, Position: 3
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# Température moteur RedBull : 287.1
#
# --- Fin du tour ---
#
# --- Tour 6 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 400 km/h, Température Pneumatiques: 72.5°, Température Moteur: 287.1°, Position: 3
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 77.05°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 151 km/h, Température Pneumatiques: 162.97°, Température Moteur: 243.62°, Position: 2
# RedBull tente un dépassement !
# RedBull dépasse Ferrari !
# RedBull: 500cv, Vitesse: 400 km/h, Température Pneumatiques: 66.7°, Température Moteur: 287.1°, Position: 2
# Ferrari: 600cv, Vitesse: 151 km/h, Température Pneumatiques: 185.79°, Température Moteur: 243.62°, Position: 3
# Mercedes tente un dépassement !
# Mercedes ne peut pas dépasser Ferrari car elle est déjà derrière.
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 68.58°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 151 km/h, Température Pneumatiques: 185.79°, Température Moteur: 243.62°, Position: 3
# Ferrari tente un dépassement !
# Ferrari dépasse RedBull !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 68.58°, Température Moteur: 217.8°, Position: 1
# RedBull: 500cv, Vitesse: 400 km/h, Température Pneumatiques: 66.7°, Température Moteur: 287.1°, Position: 3
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 144 km/h, Température Pneumatiques: 185.79°, Température Moteur: 264.86°, Position: 2
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 460 km/h, Température Pneumatiques: 66.7°, Température Moteur: 303.75°, Position: 3
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# Température moteur RedBull : 303.75
#
# --- Fin du tour ---
#
# --- Tour 7 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 460 km/h, Température Pneumatiques: 66.7°, Température Moteur: 303.75°, Position: 3
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 68.58°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 144 km/h, Température Pneumatiques: 185.79°, Température Moteur: 264.86°, Position: 2
# RedBull tente un dépassement !
# RedBull ne peut pas dépasser Mercedes directement.
# RedBull: 500cv, Vitesse: 460 km/h, Température Pneumatiques: 61.36°, Température Moteur: 303.75°, Position: 3
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 76.8°, Température Moteur: 217.8°, Position: 1
# Mercedes tente un dépassement !
# Mercedes ne peut pas dépasser Ferrari car elle est déjà derrière.
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 68.36°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 144 km/h, Température Pneumatiques: 185.79°, Température Moteur: 264.86°, Position: 2
# Ferrari tente un dépassement !
# Ferrari ne peut pas dépasser RedBull car elle est déjà derrière.
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 68.36°, Température Moteur: 217.8°, Position: 1
# RedBull: 500cv, Vitesse: 460 km/h, Température Pneumatiques: 61.36°, Température Moteur: 303.75°, Position: 3
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 134 km/h, Température Pneumatiques: 185.79°, Température Moteur: 246.46°, Position: 2
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 529 km/h, Température Pneumatiques: 61.36°, Température Moteur: 321.36°, Position: 3
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# Température moteur RedBull : 321.36
#
# --- Fin du tour ---
#
# --- Tour 8 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 529 km/h, Température Pneumatiques: 61.36°, Température Moteur: 321.36°, Position: 3
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 68.36°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 134 km/h, Température Pneumatiques: 185.79°, Température Moteur: 246.46°, Position: 2
# RedBull tente un dépassement !
# RedBull dépasse Ferrari !
# RedBull: 500cv, Vitesse: 529 km/h, Température Pneumatiques: 56.45°, Température Moteur: 321.36°, Position: 2
# Ferrari: 600cv, Vitesse: 134 km/h, Température Pneumatiques: 211.8°, Température Moteur: 246.46°, Position: 3
# Mercedes tente un dépassement !
# Mercedes ne peut pas dépasser RedBull car elle est déjà derrière.
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 60.84°, Température Moteur: 217.8°, Position: 1
# RedBull: 500cv, Vitesse: 529 km/h, Température Pneumatiques: 56.45°, Température Moteur: 321.36°, Position: 2
# Ferrari tente un dépassement !
# Ferrari ne peut pas dépasser Mercedes directement.
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 60.84°, Température Moteur: 217.8°, Position: 1
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 60.84°, Température Moteur: 217.8°, Position: 1
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 126 km/h, Température Pneumatiques: 211.8°, Température Moteur: 264.19°, Position: 3
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 608 km/h, Température Pneumatiques: 56.45°, Température Moteur: 339.81°, Position: 2
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# Température moteur RedBull : 339.81
#
# --- Fin du tour ---
#
# --- Tour 9 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 608 km/h, Température Pneumatiques: 56.45°, Température Moteur: 339.81°, Position: 2
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 60.84°, Température Moteur: 217.8°, Position: 1
# Ferrari: 600cv, Vitesse: 126 km/h, Température Pneumatiques: 211.8°, Température Moteur: 264.19°, Position: 3
# RedBull tente un dépassement !
# RedBull dépasse Mercedes !
# RedBull: 500cv, Vitesse: 608 km/h, Température Pneumatiques: 51.94°, Température Moteur: 339.81°, Position: 1
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 68.14°, Température Moteur: 217.8°, Position: 2
# Mercedes tente un dépassement !
# Mercedes ne peut pas dépasser Ferrari car elle est déjà derrière.
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 60.64°, Température Moteur: 217.8°, Position: 2
# Ferrari: 600cv, Vitesse: 126 km/h, Température Pneumatiques: 211.8°, Température Moteur: 264.19°, Position: 3
# Ferrari tente un dépassement !
# Ferrari ne peut pas dépasser RedBull directement.
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 60.64°, Température Moteur: 217.8°, Position: 2
# RedBull: 500cv, Vitesse: 608 km/h, Température Pneumatiques: 51.94°, Température Moteur: 339.81°, Position: 1
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 120 km/h, Température Pneumatiques: 211.8°, Température Moteur: 251.61°, Position: 3
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 699 km/h, Température Pneumatiques: 51.94°, Température Moteur: 359.41°, Position: 1
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull fonctionne encore normalement.
# Température moteur RedBull : 359.41
#
# --- Fin du tour ---
#
# --- Tour 10 ---
# --- Début du tour ---
# RedBull: 500cv, Vitesse: 699 km/h, Température Pneumatiques: 51.94°, Température Moteur: 359.41°, Position: 1
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 60.64°, Température Moteur: 217.8°, Position: 2
# Ferrari: 600cv, Vitesse: 120 km/h, Température Pneumatiques: 211.8°, Température Moteur: 251.61°, Position: 3
# RedBull tente un dépassement !
# RedBull ne peut pas dépasser Ferrari car elle est déjà derrière.
# RedBull: 500cv, Vitesse: 699 km/h, Température Pneumatiques: 47.78°, Température Moteur: 359.41°, Position: 1
# Ferrari: 600cv, Vitesse: 120 km/h, Température Pneumatiques: 241.45°, Température Moteur: 251.61°, Position: 3
# Mercedes tente un dépassement !
# Mercedes ne peut pas dépasser Ferrari car elle est déjà derrière.
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 53.97°, Température Moteur: 217.8°, Position: 2
# Ferrari: 600cv, Vitesse: 120 km/h, Température Pneumatiques: 241.45°, Température Moteur: 251.61°, Position: 3
# Ferrari tente un dépassement !
# Ferrari dépasse Mercedes !
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 53.97°, Température Moteur: 217.8°, Position: 3
# Mercedes: 550cv, Vitesse: 200 km/h, Température Pneumatiques: 53.97°, Température Moteur: 217.8°, Position: 3
# Ferrari subit un dépassement !
# Ferrari: 600cv, Vitesse: 115 km/h, Température Pneumatiques: 241.45°, Température Moteur: 274.89°, Position: 2
# RedBull utilise DRS !
# RedBull: 500cv, Vitesse: 803 km/h, Température Pneumatiques: 47.78°, Température Moteur: 379.86°, Position: 1
# Simulation d'une panne moteur pour RedBull
# Le moteur de la RedBull est cassé et la voiture est immobilisée !
# Température moteur RedBull : 379.86
#
# --- Fin du tour ---
